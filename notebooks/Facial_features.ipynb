# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.FacialFeaturesExtractor import FacialFeaturesExtractor
from src.LandmarksGenerator import LandmarksGenerator

# %%
image_path = os.path.join(module_path, "notebooks/bella_hadid.jpg")

# %%
landmarks = LandmarksGenerator.landmarks_from_ready_image(image_path)
ffe = FacialFeaturesExtractor(keypoints=landmarks, image_path=image_path)

# %% [markdown]
# # Static parts of the face

# %% [markdown]
# ## Bi-gonial to bi-zygomatic proportion

# %% [markdown]
# Bigonial width, measured from the soft tissue overlying the most lateral point of each mandibular angle (soft tissue
# gonion), is usually 70−75% of bizygomatic width, measured from the most lateral point of the soft tissue overlying each zygomatic arch. This ratio indicates the ideal face shape in the form of a heart/diamond [1].

# %%
ffe.draw_bigonial_bizygomatic_ratio()

# %% [markdown]
# # Moving parts of the face

# %% [markdown]
# ## Eyebrows

# %% [markdown]
# The positioning of the eyebrow in both men and women is a common indicator of youth. As aging decreases skin elasticity and periorbital muscles weaken, the eyebrow tends to sag downwards.

# %% [markdown]
# According to literature [2], there are several characteristics of the ideal youthful female eyebrow:

# %% [markdown]
# 1) There is a straight medial brow segment with a takeoff angle of 15° to 25°.

# %%
ffe.draw_medial_eyebrow_tilt()

# %% [markdown]
# 2) The brow peak is located at the lateral canthus for younger women. The older the patient, the more medial the brow peak can be.

# %%
ffe.draw_brow_apex_projection()

# %% [markdown]
# ## Eyes

# %% [markdown]
# Canthal tilt is more accurately described as the inclination of the palpebral fissure (eyeopening). Bashour et al 2007 found that canthal tilt is a significant indicator in facial attractiveness with 93% of participants in the study preferring positive canthal tilts rather than negative ones.

# %% [markdown]
# According to [3] the lateral canthal tilt (LCT) for an average Asian face was 9.77°, and for an attractive Asian face it was 8.64°. The LCT for an average Caucasian face was 4.12° and for an attractive Caucasian face it was 7.13°. For an average African face the LCT was 5.39° and in an attractive African face it was 9.98°. The average Asian face has a unique Mongolian
# slant but the position of lateral canthus is relatively lower in attractive Asian faces. Interestingly, attractive African and Caucasian faces have a relatively greater LCT than average faces from the same race and attractive African and Caucasian faces have an acute eye shape much like a jaguar’s eye.

# %%
ffe.draw_canthal_tilt()

# %% [markdown]
# ## Lips

# %% [markdown]
# One of the many features that contribute to the aging appearance of the perioral region is the downward turn to the oral commissures. This downward turn, which often extends to a significant oral commissure groove and ‘‘marionette’’ appearance,
# gives a sad, tired, almost angry look in some patients. This senility can be extreme and causes lateral oral commissure drooling and angular cheilitis [4].

# %%
ffe.draw_lip_line_cant()

# %% [markdown]
# The fundamental proportions of the lips change as a person ages, with lengthening of the cutaneous portion of the upper lip and volume loss and thinning of the upper lip vermilion. It is considered to be, that in youthful Caucasians, the ideal ratio of the vertical height of the upper lip to that of the lower lip is 1:1.6 [5]. Meanwhile, in a 2017 study [6] researchers found that an upper to lower lip ratio closer to 1:1 was considered the most attractive. These findings are more consistent with recent trends in cosmetic medicine, with many clients aiming for a fuller upper lip.

# %%
ffe.draw_lips_ratio()

# %% [markdown]
# According to [7] the upper lip height occupies about one third of the face lower third in both genders (males 33.04%, females 32.38%)

# %%
ffe.draw_upper_lip_ratio()

# %% [markdown]
# # Bibliography

# %% [markdown]
# 1. Naini FB, Gill DS. Facial aesthetics: 2. Clinical assessment. Dent Update. 2008 Apr;35(3):159-62, 164-6, 169-70.
# 2. Griffin GR, Kim JC. Ideal female brow aesthetics. Clin Plast Surg. 2013 Jan;40(1):147-55.
# 3. Rhee SC, Woo KS, Kwon B. Biometric study of eyelid shape and dimensions of different races with references to beauty. Aesthetic Plast Surg. 2012 Oct;36(5):1236-45
# 4. Perkins, S. W. The Corner of the Mouth Lift and Management of the Oral Commissure Grooves. Facial Plastic Surgery Clinics of North America, 2007, 15(4), 471–476.
# 5. Mandy S. Art of the lip. Dermatol Surg 2007;33:521-2
# 6. Heidekrueger PI, Juran S, Szpalski C, Larcher L, Ng R, Broer PN. The current preferred female lip ratio. J Craniomaxillofac Surg. 2017 May;45(5):655-660.
# 7. Anic-Milosevic, S., Mestrovic, S., Prlić, A., & Slaj, M. (2010). Proportions in the upper lip–lower lip–chin area of the lower face as determined by photogrammetric method. Journal of Cranio-Maxillofacial Surgery, 38(2), 90–95.
